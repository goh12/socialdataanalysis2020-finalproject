# %% [markdown]
# Datasets source : https://www.kaggle.com/christophercorrea/dc-residential-properties
#
# Dataset : DC_Properties.csv
#
# Key-variabls:
# - <b>PRICE</b>: Price of most recent sale (Numeric/Target variable)
# - <b>X</b>: longitude (Numeric/non-linear relationship)
# - <b>Y</b>: latitude (Numeric/non-linear relationship)
# - <b>LANDAREA</b>: Land area of property in square feet (Numeric)
# - <b>GBA</b>: Gross building area in square feet (Numeric)
# - <b>LIVING_GBA</b>: Gross building area in square feet
# - <b>BATHRM</b>: Number of bathrooms (Count)
# - <b>ROOMS</b>: Number of Rooms (Count)
# - <b>KITCHENS</b>: Number of kitchens (Count)
# - <b>BEDRM</b>: Number of Bedrooms (Count)
# - <b>CNDTN</b>: Condition (Categorical)
#
# Relevant-variables:
# - <b>STYLE</b>: Style
#
#
#
#
# Other-variables:
#
# - <b>LATITUDE</b>: Latitude
# - <b>LONGITUDE</b>: Longitude
# - <b>HF_BATHRMNumber</b>: of Half Bathrooms (no bathtub or shower)
# - <b>HEAT</b>: Heating
# - <b>AC</b>: Cooling
# - <b>NUM_UNITS</b>:Number of Units
# - <b>AYB</b>: The earliest time the main portion of the building was built
# - <b>YR_RMDL</b>: Year structure was remodeled
# - <b>EYB</b>: The year an improvement was built more recent than actual year built
# - <b>STORIES</b>: Number of stories in primary dwelling
# - <b>SALEDATE</b>: Date of most recent sale
# - <b>QUALIFIED</b>: Qualified
# - <b>SALE_NUM</b>: Sale Number
# - <b>BLDG_NUM</b>: Building Number on Property
# - <b>STRUCT</b>: Structure
# - <b>GRADE</b>: Grade
# - <b>EXTWALL</b>: Extrerior wall
# - <b>ROOF</b>: Roof type
# - <b>INTWALL</b>: Interior wall
# - <b>FIREPLACES</b>: Number of fireplaces
# - <b>USECODE</b>: Property use code
# - <b>GIS_LAST_MOD_DTTM</b>: Last Modified Date
# - <b>SOURCE</b>: Raw Data Source
# - <b>CMPLX_NUM</b>: Complex number
# - <b>FULLADDRESS</b>: Full Street Address
# - <b>CITY</b>: City
# - <b>STATE</b>: State
# - <b>ZIPCODE</b>: Zip Code
# - <b>NATIONALGRID</b>: Address location national grid coordinate spatial address
# - <b>ASSESSMENT_NBHD</b>: Neighborhood ID
# - <b>ASSESSMENT_SUBNBHD</b>: Subneighborhood ID
# - <b>CENSUS_TRACT</b>: Census tract
# - <b>CENSUS_BLOCK</b>: Census block
# - <b>WARD</b>: Ward (District is divided into eight wards, each with approximately 75,000 residents)
# - <b>SQUARE</b>: Square (from SSL)
# - <b>QUADRANT</b>: City quadrant (NE,SE,SW,NW)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
import seaborn as sns
df = pd.read_csv('../Data/DC_Properties.csv')
print(df.shape)
# Out:
# (158957, 49)
# C:\Users\Sverrir\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df[df.FIREPLACES >= 200]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 111896      111896       1          0  Forced Air  Y        NaN      4      1
# 115370      115370       1          0  Forced Air  Y        NaN      2      0
# 123974      123974       2          0     Ht Pump  Y        NaN      4      2
# 134069      134069       1          0  Forced Air  Y        NaN      3      1
# 134928      134928       1          0  Forced Air  Y        NaN      2      0
# 146813      146813       2          1  Forced Air  Y        NaN      5      2
#
#            AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD  \
# 111896  1960.0   1978.0  ... -77.084688   Wesley Heights
# 115370  1962.0   1980.0  ... -77.052481     Foggy Bottom
# 123974  2016.0      NaN  ... -76.985702         Trinidad
# 134069  1963.0   2006.0  ... -77.031057    Central-tri 3
# 134928  1963.0   2006.0  ... -77.031057    Central-tri 3
# 146813  1874.0   2007.0  ... -77.002646       Old City 1
#
# ...

# %%
sorted(-df.FIREPLACES)
# Out:
# [-293920,
#  -4068,
#  -1601,
#  -1017,
#  -922,
#  -200,
#  -13,
#  -13,
#  -13,
#  -12,
#  -12,
#  -12,
#  -11,
#  -11,
#  -11,
#  -10,
#  -10,
#  -10,
#  -10,
#  -10,
#  -10,
#  -10,
#  -10,
#  -9,
#  -9,
#  -9,
#  -9,
#  -9,
#  -9,
#  -9,
#  -9,
#  -9,
#  -9,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -8,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -7,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
#  -6,
# ...

# %%
print(df.GBA.quantile(0.99))
print(df.GBA.quantile(0.01))
# Out:
# 4815.0
# 768.0

# %%
df.SOURCE.value_counts()
# Out:
# Residential    106696
# Condominium     52261
# Name: SOURCE, dtype: int64

# %%
df.WARD.unique()
# Out:
# array(['Ward 2', 'Ward 1', 'Ward 6', 'Ward 5', 'Ward 3', 'Ward 4',
#        'Ward 7', 'Ward 8', nan], dtype=object)

# %%
pd.set_option('display.max_columns', 500)
df[df.SOURCE == 'Residential']
df[df.SOURCE == 'Condominium'].groupby(['LATITUDE','LONGITUDE']).count().sort_values('HEAT')
# Out:
#                       Unnamed: 0  BATHRM  HF_BATHRM  HEAT    AC  NUM_UNITS  \
# LATITUDE  LONGITUDE
# 38.909311 -77.066976           1       1          1     1     1          0
# 38.916627 -77.004906           2       2          2     2     2          0
# 38.901929 -76.993144           2       2          2     2     2          0
# 38.901946 -76.994401           2       2          2     2     2          0
# 38.940405 -77.018401           2       2          2     2     2          0
# ...                          ...     ...        ...   ...   ...        ...
# 38.903141 -77.017776         504     504        504   504   504          0
# 38.874789 -77.016301         524     524        524   524   524          0
# 38.909443 -77.039693         592     592        592   592   592          0
# 38.880821 -77.014271        1022    1022       1022  1022  1022          0
# 38.934668 -77.084688        1126    1126       1126  1126  1126          0
#
# ...

# %%
df.groupby(['SOURCE']).count()
# Out:
#              Unnamed: 0  BATHRM  HF_BATHRM    HEAT      AC  NUM_UNITS   ROOMS  \
# SOURCE
# Condominium       52261   52261      52261   52261   52261          0   52261
# Residential      106696  106696     106696  106696  106696     106696  106696
#
#               BEDRM     AYB  YR_RMDL     EYB  STORIES  SALEDATE  PRICE  \
# SOURCE
# Condominium   52261   52231    31649   52261        0     48004  40316
# Residential  106696  106455    49279  106696   106652     84183  57900
#
#              QUALIFIED  SALE_NUM     GBA  BLDG_NUM   STYLE  STRUCT   GRADE  \
# SOURCE
# Condominium      52261     52261       0     52261       0       0       0
# Residential     106696    106696  106696    106696  106696  106696  106696
#
#               CNDTN  EXTWALL    ROOF  INTWALL  KITCHENS  FIREPLACES  USECODE  \
# SOURCE
# Condominium       0        0       0        0         0       52261    52261
# Residential  106696   106696  106696   106696    106695      106696   106696
#
# ...

# %%
df.groupby(['ROOF']).mean().PRICE.sort_values().plot(kind='barh')

# %%
df.groupby(['EXTWALL']).mean().PRICE.sort_values().plot(kind='barh')

# %%
df.groupby(['CNDTN']).mean().PRICE.sort_values().plot(kind='barh')

# %%
df.groupby(['STYLE']).mean().PRICE.sort_values().plot(kind='barh')

# %%
price_by_location = df.groupby(['X','Y']).mean().PRICE

# %%
price_by_location_99 = price_by_location[price_by_location<np.quantile(price_by_location.dropna(),0.99)]
plt.hist(price_by_location_99,bins=100)
plt.xlim(0,)
plt.show()

# %%
def scatter_heat_map(df,variable,title):
    var_by_loc =df.groupby(['X','Y']).mean().loc[:,variable]
    var_by_loc_99 = var_by_loc[var_by_loc<np.quantile(var_by_loc.dropna(),0.99)]
    plt.figure(figsize=(10,10))
    plt.scatter(var_by_loc_99.index.get_level_values('X'),var_by_loc_99.index.get_level_values('Y'),c=var_by_loc_99)
    plt.title(title,fontsize=25)
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
scatter_heat_map(df,'PRICE','Price Map')

# %%
scatter_heat_map(df,'GBA','asdf')

# %%
df.GBA.unique()
# Out:
# array([2522., 2567., 2484., ..., 5712., 4995.,   nan])

# %%
df.CNDTN.unique()
# Out:
# array(['Good', 'Very Good', 'Average', 'Fair', 'Excellent', 'Poor',
#        'Default', nan], dtype=object)

# %%
df.HEAT.unique()
# Out:
# array(['Warm Cool', 'Hot Water Rad', 'Forced Air', 'Elec Base Brd',
#        'Ht Pump', 'Electric Rad', 'Wall Furnace', 'Water Base Brd',
#        'Evp Cool', 'Air Exchng', 'No Data', 'Ind Unit', 'Gravity Furnac',
#        'Air-Oil'], dtype=object)

# %%
df_loc = df.loc[:,['LATITUDE','LONGITUDE']].dropna()

# %%
plt.figure(figsize=(10,10))
plt.hist2d(df_loc.LONGITUDE,df_loc.LATITUDE,bins=100)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(df.LIVING_GBA,df.PRICE)
# plt.ylim(0,0.1e8)

# %%
df[df.PRICE>(1.3*1e8)].count()
# Out:
# Unnamed: 0            242
# BATHRM                242
# HF_BATHRM             242
# HEAT                  242
# AC                    242
# NUM_UNITS               0
# ROOMS                 242
# BEDRM                 242
# AYB                   242
# YR_RMDL               242
# EYB                   242
# STORIES                 0
# SALEDATE              242
# PRICE                 242
# QUALIFIED             242
# SALE_NUM              242
# GBA                     0
# BLDG_NUM              242
# STYLE                   0
# STRUCT                  0
# GRADE                   0
# CNDTN                   0
# EXTWALL                 0
# ROOF                    0
# INTWALL                 0
# KITCHENS                0
# FIREPLACES            242
# USECODE               242
# LANDAREA              242
# GIS_LAST_MOD_DTTM     242
# SOURCE                242
# CMPLX_NUM             242
# LIVING_GBA            242
# FULLADDRESS             0
# CITY                    0
# ...

# %%
(1.3*1e8)/242
# Out:
# 537190.0826446281

# %%
df[df.PRICE>(1.3*1e8)]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM     HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 125662      125662       1          0  Ht Pump  Y        NaN      3      1
# 125663      125663       2          0  Ht Pump  Y        NaN      4      1
# 125664      125664       2          0  Ht Pump  Y        NaN      4      2
# 125670      125670       1          0  Ht Pump  Y        NaN      3      1
# 125845      125845       1          0  Ht Pump  Y        NaN      3      1
# ...            ...     ...        ...      ... ..        ...    ...    ...
# 132836      132836       1          0  Ht Pump  Y        NaN      3      1
# 132846      132846       1          0  Ht Pump  Y        NaN      4      1
# 132847      132847       2          0  Ht Pump  Y        NaN      3      1
# 132848      132848       1          0  Ht Pump  Y        NaN      3      1
# 132855      132855       1          0  Ht Pump  Y        NaN      3      1
#
# ...

# %%
df[df.PRICE>(1.3*1e8)].iloc[0]
# Out:
# Unnamed: 0                         125662
# BATHRM                                  1
# HF_BATHRM                               0
# HEAT                              Ht Pump
# AC                                      Y
# NUM_UNITS                             NaN
# ROOMS                                   3
# BEDRM                                   1
# AYB                                  1989
# YR_RMDL                              2005
# EYB                                  1989
# STORIES                               NaN
# SALEDATE              2007-04-10 00:00:00
# PRICE                         1.37428e+08
# QUALIFIED                               U
# SALE_NUM                                1
# GBA                                   NaN
# BLDG_NUM                                1
# STYLE                                 NaN
# STRUCT                                NaN
# GRADE                                 NaN
# CNDTN                                 NaN
# ...

# %%
plt.figure(figsize=(10,10))
plt.scatter(df.GBA,df.PRICE)
# plt.ylim(0,0.1e8)

# %%
plt.figure(figsize=(8,8))
sns.lmplot('GBA','PRICE',df,scatter_kws={"alpha": 0.3},line_kws={'color':'red'})
plt.xlim(0,10000)
plt.ylim(0,0.8e7)
plt.xlabel('Size [ft^2]',fontsize=10)
plt.ylabel('Price [$million]',fontsize=10)
plt.title('Price per square foot',fontsize=15)
plt.yticks(np.arange(0,1e7,1_000_000),np.arange(0,10,1).astype(int))
plt.show()

# %%
import datetime as dt

# %%
df.loc[:,'SALEDATE'] = pd.to_datetime(df.loc[:,'SALEDATE'],format='%Y-%m-%d %H:%M:%S')

# %%
plt.figure(figsize=(8,8))
plt.scatter(df.loc[:,'SALEDATE'],df.loc[:,'PRICE'])
# plt.xlim(0.4e18,1e18)
plt.ylim(0,10e6)
plt.xlabel('Size [ft^2]')
# plt.yticks(np.arange(0,1.4e7,500_000),)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
plt.hist(df[df.PRICE<0.1e8].PRICE,bins=100)
plt.xlim(0,0.04e8)
# Out:
# (0, 4000000.0)

# %%
from  missingno import matrix

# %%
matrix(df.loc[df.PRICE.dropna().index,:])

# %%
df.loc[:,['GBA','KITCHENS']].dropna()
# Out:
#            GBA  KITCHENS
# 0       2522.0       2.0
# 1       2567.0       2.0
# 2       2522.0       2.0
# 3       2484.0       2.0
# 4       5255.0       1.0
# ...        ...       ...
# 106691  1600.0       2.0
# 106692  1600.0       2.0
# 106693  1600.0       2.0
# 106694  1600.0       2.0
# 106695  1600.0       2.0
#
# [106695 rows x 2 columns]

# %%
X = df.loc[:,['GBA','KITCHENS']]
y = df.loc[:,'PRICE']

# %%
X = X.dropna()
y = y.dropna()
X = X.loc[y.index.intersection(X.index)]
y = y.loc[X.index]

# %%
len(X)
# Out:
# 57899

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
import shapefile as shp

# %%
# First plot: All districts with number inside

def map_with_labels(df_geo,fig):
#     plt.figure()
    ax = plt.axes() # get current axes
    ax.set_aspect('equal') # to prevent distortion
    
    
    for district in df_geo.iterrows():
        # Plot outlines
        x_lon = np.array(district[1].coords)[:,0]
        y_lat = np.array(district[1].coords)[:,1]
        ax.plot(x_lon,y_lat, color='black',fillstyle='full')
        
        # Labels (find center and insert text)
        x0 = np.mean(x_lon)
        y0 = np.mean(y_lat)
#         plt.text(x0, y0, district[1].OBJECTID, fontsize=10)
    return ax

# %%
def shp_to_df(sf):
    # Extract labels and data
    fields = [x[0] for x in sf.fields[1:]] # Column values
    records = sf.records() # data for dataframe
    shape_data = [x.points for x in sf.shapes()]

    # Create dataframe with values
    df_geo = pd.DataFrame(columns=fields, data=records)
    df_geo['coords'] = shape_data
    
    return df_geo

Shp_path = '../Data/Census_Tracts_in_2010.shp'
sf = shp.Reader(Shp_path)
df_geo = shp_to_df(sf)

# %%
f = plt.figure(figsize=(10,10))
ax = map_with_labels(df_geo,f)

# %%
# Map plot with color gradients based on values
def map_with_color_values(df_geo, value_dict, cmap):
    fig = plt.figure(figsize=(10,10))
    plt.tight_layout()
    ax = plt.axes() # get current axes
    ax.set_aspect('equal') # to prevent distortion
    plt.xticks([])
    plt.yticks([])
    plt.title('Median price by district',fontsize=25)
    plt.ylabel("Longitude")
    plt.xlabel("Latitude")
    
    """since the sum of the probabilities is 1, we only need to
    map 1 probability to a gradient, then the other proba is
    the included. One probability is the other one inverted """
    first_items = [i for i in value_dict.values()]
    # Scale values from 0 to 1
    c_min, c_max = min(first_items),max(first_items)
    c_values = [(i - c_min)/(c_max-c_min) for i in first_items]
    
    # Pick color map
    cmap = plt.cm.get_cmap('RdBu')
    
    # Get corresponding colors from map
    color_sq = [cmap(x) for x in c_values]
    
    for color,district in zip(color_sq,df_geo.iterrows()):
        
        # Plot outlines
        x_lon = np.array(district[1].coords)[:,0]
        y_lat = np.array(district[1].coords)[:,1]
        
        c_val = 'black'
        
        ax.fill(x_lon,y_lat, color=color)
        ax.plot(x_lon,y_lat, color='black',lw=0.5)
    sm = plt.cm.ScalarMappable(cmap="coolwarm", norm=plt.Normalize(vmin=np.min([value_dict[x] for x in value_dict]), vmax=np.max([value_dict[x] for x in value_dict])))
    cbar = plt.colorbar(sm, ticks=np.arange(0,1_125_000,250_000), orientation="horizontal",fraction=0.046,pad=0.11,)
    
#     cbar.ax.set_xticklabels(['/'.join(type_1), '/'.join(type_2)])
    
#     plt.savefig("./Frames/{}.png".format(h),dpi=150)
#     plt.close()
    plt.show()
        
cmap = plt.get_cmap('BuPu')

# %%
df_locs = [row for row in zip(df.X,df.Y)]

# %%
from matplotlib import path
df.loc[:,'GEOID'] = None
for gid,coords in zip(df_geo.GEOID,df_geo.coords):
#     x,y = np.array(coords).T
    p = path.Path(coords)  # square with legs length 1 and bottom left corner at the origin
    flags = p.contains_points(df_locs)
    df.loc[flags,'GEOID'] = gid

# %%
df.loc[:,'PPSF'] = None 
df.loc[df.SOURCE == 'Residential','PPSF'] = df.loc[df.SOURCE == 'Residential','PRICE']/df.loc[df.SOURCE == 'Residential','GBA'].astype(int)
df.loc[df.SOURCE == 'Condominium','PPSF'] = df.loc[df.SOURCE == 'Condominium','PRICE']/df.loc[df.SOURCE == 'Condominium','LIVING_GBA'].astype(int)
df.loc[:,'PPSF'] = df.loc[df.loc[:,'PPSF'] < 10**100,'PPSF'].astype(int)

# %%
df.loc[df.SOURCE == 'Condominium','PPSF'].dropna().hist(bins=100)

# %%
df.loc[df.SOURCE == 'Residential','PPSF'].dropna().hist(bins=100)

# %%
import missingno
missingno.matrix(df)
plt.show()

# %%
df.groupby(['GEOID']).median().sort_index()
# Out:
#              Unnamed: 0  BATHRM  HF_BATHRM  NUM_UNITS  ROOMS  BEDRM     AYB  \
# GEOID
# 11001000100     21869.5     2.0        1.0        1.0    6.0    2.0  1900.0
# 11001000202     20496.5     2.0        1.0        1.0    6.0    3.0  1900.0
# 11001000300     22551.5     2.0        0.0        1.0    7.0    3.0  1936.0
# 11001000400     37575.0     3.0        1.0        1.0    8.0    4.0  1941.0
# 11001000501    150746.0     2.0        0.0        1.0    5.0    2.0  1963.0
# ...                 ...     ...        ...        ...    ...    ...     ...
# 11001010700    117839.5     1.0        0.0        2.0    3.0    1.0  1974.0
# 11001010800    116657.5     1.0        0.0        1.0    2.0    0.0  1974.0
# 11001010900    106949.5     1.0        0.0        2.0    5.0    2.0  1949.0
# 11001011000    154511.0     1.0        0.0        1.0    3.0    1.0  1967.0
# 11001011100     80159.0     2.0        0.0        1.0    6.0    3.0  1927.0
#
# ...

# %%
df
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# ...            ...     ...        ...            ... ..        ...    ...
# 158952      158952       1          0     Forced Air  Y        NaN      3
# 158953      158953       1          0     Forced Air  Y        NaN      4
# 158954      158954       2          0     Forced Air  Y        NaN      4
# 158955      158955       1          0      Warm Cool  Y        NaN      2
# 158956      158956       1          0      Warm Cool  Y        NaN      2
#
#         BEDRM     AYB  YR_RMDL   EYB  STORIES   SALEDATE      PRICE QUALIFIED  \
# ...

# %%
geo_prices = df.groupby(['GEOID']).median().sort_index().loc[:,'PPSF']

# %%
geo_prices
# Out:
# GEOID
# 11001000100    655.0
# 11001000202    634.5
# 11001000300    513.5
# 11001000400    491.0
# 11001000501    473.0
#                ...
# 11001010700    524.5
# 11001010800    434.0
# 11001010900     84.0
# 11001011000    304.0
# 11001011100    230.0
# Name: PPSF, Length: 175, dtype: float64

# %%
d = {ind:val for ind,val in zip(geo_prices.index,geo_prices.values)}
h = geo_prices.index.values

map_with_color_values(df_geo,d,cmap)

# %%
geo_prices = df.groupby(['GEOID']).median().sort_index().loc[:,'PRICE']
d = {ind:val for ind,val in zip(geo_prices.index,geo_prices.values)}
h = geo_prices.index.values

map_with_color_values(df_geo,d,cmap)

# %%
df.loc[:,'SALEDATE'] = pd.to_datetime(df.loc[:,'SALEDATE'],format='%Y-%m-%d %H:%M:%S')
df.loc[:,'SALEYEAR'] = [x.year for x in df.SALEDATE]

# %%
max(geo_prices)
# Out:
# 2015.0

# %%
geo_prices = 2015-df.groupby(['GEOID']).median().sort_index().loc[:,'SALEYEAR']
d = {ind:val for ind,val in zip(geo_prices.index,geo_prices.values)}
h = geo_prices.index.values

map_with_color_values(df_geo,d,cmap)

# %%
import json

from bokeh.io import output_file, show
from bokeh.models import GeoJSONDataSource
from bokeh.plotting import figure
from bokeh.sampledata.sample_geojson import geojson

output_file("geojson.html")

data = json.loads(geojson)
for i in range(len(data['features'])):
    data['features'][i]['properties']['Color'] = ['blue', 'red'][i%2]

geo_source = GeoJSONDataSource(geojson=json.dumps(data))

TOOLTIPS = [
    ('Organisation', '@OrganisationName')
]

p = figure(background_fill_color="lightgrey", tooltips=TOOLTIPS)
p.circle(x='x', y='y', size=15, color='Color', alpha=0.7, source=geo_source)

show(p)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT',
#        'GEOID', 'PPSF'],
#       dtype='object')

# %%
plt.figure(figsize=(7,15))
df.ASSESSMENT_NBHD.value_counts().plot(kind='barh')

# %%
top_10 = df.ASSESSMENT_NBHD.value_counts()[:10].index

# %%
top_10_df = df[df['ASSESSMENT_NBHD'].isin(top_10)]
mean_df = top_10_df.groupby(['ASSESSMENT_NBHD']).mean()

# %%
mean_df.loc[:,'PRICE'].plot(kind='bar')
plt.ylabel('Mean price')
plt.xlabel('Neighbourhood')
# Out:
# Text(0.5, 0, 'Neighbourhood')

# %%
mean_df.loc[:,'GBA'].plot(kind='bar')
plt.ylabel('Mean size [Sq ft]')
plt.xlabel('Neighbourhood')
# Out:
# Text(0.5, 0, 'Neighbourhood')

# %%
mean_df
# Out:
#                      Unnamed: 0    BATHRM  HF_BATHRM  NUM_UNITS     ROOMS  \
# ASSESSMENT_NBHD
# Brightwood         61741.581712  1.768482   0.573200   1.074826  6.875486
# Brookland          78625.515682  1.700518   0.515682   1.133262  6.589982
# Chevy Chase        44724.921741  2.338812   0.810796   1.005026  7.605342
# Columbia Heights   90353.376399  1.743403   0.305256   1.268510  5.792590
# Congress Heights  105355.849228  1.649186   0.456968   1.287606  6.498203
# Deanwood           89390.287314  1.578472   0.398629   1.138612  6.386428
# Mt. Pleasant       95170.598963  1.840573   0.371915   1.449863  5.714956
# Old City 1         44201.906333  1.763800   0.476600   1.265645  6.293133
# Old City 2         93199.572975  1.634748   0.260984   1.553741  4.840844
# Petworth           66492.347462  1.736992   0.420686   1.136630  7.094892
#
#                      BEDRM          AYB      YR_RMDL          EYB   STORIES  \
# ASSESSMENT_NBHD
# ...

# %%
mean_df.plot()

# %%
mean_df.loc[:,'GBA'].plot(kind='bar')
plt.ylabel('Mean size [Sq ft]')
plt.xlabel('Neighbourhood')
# Out:
# Text(0.5, 0, 'Neighbourhood')

# %%
# districts = top_10_df.loc[:,'ASSESSMENT_NBHD'].value_counts().index.values
# # print(districts)
# f,axes = plt.subplots(len(districts)//2,2, figsize=(20,10),sharex=True)

# bins = np.linspace(df_sub.PRICE.quantile(0),df_sub.PRICE.quantile(0.95),100)
# for district,ax in zip(districts,np.ravel(axes)):
#     df_sub = df.loc[df['ASSESSMENT_NBHD'] == district]
#     df_sub = df_sub[df_sub.PRICE < df_sub.PRICE.quantile(0.95)]
#     df_sub.PRICE.plot(kind='hist',bins=bins,ax=ax,color='grey',edgecolor='black')
    
    
# plt.show()

# %%
df.AYB.hist(bins=100)
plt.xlabel('year')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
key_vars = ['PRICE','X','Y','ROOMS','GBA','LANDAREA','BATHRM','KITCHENS','BEDRM'] #,'CNDTN'
df_key = df.loc[:,key_vars].dropna()

# %%
y = df_key.PRICE
X = df_key.drop(['PRICE'],axis='columns')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
y_pred_test = reg.predict(X_test)
y_pred_train = reg.predict(X_train)
print('score:',r2_score(y_test,y_pred_test))
print('score:',r2_score(y_train,y_pred_train))
# Out:
# score: 0.48302418341864783
# score: 0.4472914687479044

# %%
reg = LinearRegression()
reg.fit(X,y)
y_pred = reg.predict(X)
print('score:',r2_score(y,y_pred))
# Out:
# score: 0.45048602842923235

# %%
reg = RandomForestRegressor(n_estimators=200,n_jobs=-1)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
print('score:',r2_score(y_test,y_pred))
# Out:
# score: 0.6178117098717493

# %%
import seaborn as sns

sns.set(style="white")

df_tmp = df_key.sample(1000)

g = sns.PairGrid(df_tmp, diag_sharey=False)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot, lw=2)
# Out:
# C:\Users\Sverrir\Anaconda3\lib\site-packages\statsmodels\nonparametric\kernels.py:128: RuntimeWarning: divide by zero encountered in true_divide
#   return (1. / np.sqrt(2 * np.pi)) * np.exp(-(Xi - x)**2 / (h**2 * 2.))
# C:\Users\Sverrir\Anaconda3\lib\site-packages\statsmodels\nonparametric\kernels.py:128: RuntimeWarning: invalid value encountered in true_divide
#   return (1. / np.sqrt(2 * np.pi)) * np.exp(-(Xi - x)**2 / (h**2 * 2.))
# C:\Users\Sverrir\Anaconda3\lib\site-packages\statsmodels\nonparametric\_kernel_base.py:513: RuntimeWarning: invalid value encountered in true_divide
#   dens = Kval.prod(axis=1) / np.prod(bw[iscontinuous])
# C:\Users\Sverrir\Anaconda3\lib\site-packages\matplotlib\contour.py:1520: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# C:\Users\Sverrir\Anaconda3\lib\site-packages\matplotlib\contour.py:1521: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# ...
